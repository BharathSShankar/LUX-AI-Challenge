# %%
import os
import gym
from stable_baselines3 import PPO
# RL Algorithms: https://stable-baselines3.readthedocs.io/en/master/guide/algos.html

model_dir = "models/PPO"
log_dir = "logs/"

if not os.path.exists(model_dir):
    os.makedirs(model_dir)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

env = gym.make("LunarLander-v2")
env.reset()
# Out:
# (array([-0.0030427 ,  1.4111767 , -0.30820382,  0.01139736,  0.00353248,
#          0.06981281,  0.        ,  0.        ], dtype=float32),
#  {})

# %%
model = PPO('MlpPolicy', env, verbose=1)
TIMESTEPS = 10000
for i in range(30):
    model.learn(total_timesteps=TIMESTEPS,
                reset_num_timesteps=False,
                tb_log_name="PPO")
    model.save(f"{model_dir}/PPO_{i * TIMESTEPS}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.3     |
# |    ep_rew_mean     | -163     |
# | time/              |          |
# |    fps             | 4212     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.4        |
# |    ep_rew_mean          | -163        |
# | time/                   |             |
# |    fps                  | 2910        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007571294 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.00199    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 721         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00817    |
# |    value_loss           | 1.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.4        |
# |    ep_rew_mean          | -170        |
# | time/                   |             |
# |    fps                  | 2678        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008220518 |
# |    clip_fraction        | 0.0239      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000245   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 468         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 1.09e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.3        |
# |    ep_rew_mean          | -155        |
# | time/                   |             |
# |    fps                  | 2592        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007538702 |
# |    clip_fraction        | 0.0405      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.000341    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 477         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00938    |
# |    value_loss           | 1.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.6        |
# |    ep_rew_mean          | -159        |
# | time/                   |             |
# |    fps                  | 2500        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010282835 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00666    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 421         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 639         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.7     |
# |    ep_rew_mean     | -156     |
# | time/              |          |
# |    fps             | 4035     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 12288    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.8         |
# |    ep_rew_mean          | -150         |
# | time/                   |              |
# |    fps                  | 2949         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0053721657 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000708     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 222          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00595     |
# |    value_loss           | 588          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.8        |
# |    ep_rew_mean          | -145        |
# | time/                   |             |
# |    fps                  | 2665        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007368938 |
# |    clip_fraction        | 0.0194      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.00153    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 297         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00588    |
# |    value_loss           | 511         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | -155        |
# | time/                   |             |
# |    fps                  | 2527        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008346362 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -0.065      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 326         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 342         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 119         |
# |    ep_rew_mean          | -152        |
# | time/                   |             |
# |    fps                  | 2134        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010449588 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.000347   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 142         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 324         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -138     |
# | time/              |          |
# |    fps             | 4010     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 22528    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 124          |
# |    ep_rew_mean          | -132         |
# | time/                   |              |
# |    fps                  | 2495         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0096274465 |
# |    clip_fraction        | 0.0578       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | -0.453       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 122          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00593     |
# |    value_loss           | 255          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 140          |
# |    ep_rew_mean          | -122         |
# | time/                   |              |
# |    fps                  | 2195         |
# |    iterations           | 3            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0099822255 |
# |    clip_fraction        | 0.0794       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 71.8         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 223          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 2185        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009733867 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 147         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 2008        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009623272 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 100         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00821    |
# |    value_loss           | 237         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 172      |
# |    ep_rew_mean     | -96      |
# | time/              |          |
# |    fps             | 2431     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 32768    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | -89.9        |
# | time/                   |              |
# |    fps                  | 1800         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0059637045 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.279        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.6         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00853     |
# |    value_loss           | 173          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -84.8       |
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009656243 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00881    |
# |    value_loss           | 188         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 214          |
# |    ep_rew_mean          | -79.9        |
# | time/                   |              |
# |    fps                  | 1481         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0068782344 |
# |    clip_fraction        | 0.0697       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.4         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00643     |
# |    value_loss           | 251          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 226         |
# |    ep_rew_mean          | -73.7       |
# | time/                   |             |
# |    fps                  | 1516        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.013062056 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.4        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 126         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | -72      |
# | time/              |          |
# |    fps             | 1424     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 43008    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 259         |
# |    ep_rew_mean          | -68.3       |
# | time/                   |             |
# |    fps                  | 1145        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009534284 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.4        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00635    |
# |    value_loss           | 79.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 272         |
# |    ep_rew_mean          | -65.3       |
# | time/                   |             |
# |    fps                  | 1159        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008769963 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.2        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00833    |
# |    value_loss           | 116         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 282          |
# |    ep_rew_mean          | -66.2        |
# | time/                   |              |
# |    fps                  | 1096         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0095009385 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.676        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.5         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00969     |
# |    value_loss           | 81.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 299        |
# |    ep_rew_mean          | -63.5      |
# | time/                   |            |
# |    fps                  | 1047       |
# |    iterations           | 5          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01206713 |
# |    clip_fraction        | 0.0607     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.582      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 32.6       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00785   |
# |    value_loss           | 78.4       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | -61.8    |
# | time/              |          |
# |    fps             | 1159     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 53248    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 336         |
# |    ep_rew_mean          | -61.2       |
# | time/                   |             |
# |    fps                  | 925         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007842615 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0574      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.6        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00692    |
# |    value_loss           | 203         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 353        |
# |    ep_rew_mean          | -58.7      |
# | time/                   |            |
# |    fps                  | 863        |
# |    iterations           | 3          |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01025825 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.164      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.2       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00828   |
# |    value_loss           | 26.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 371         |
# |    ep_rew_mean          | -56.2       |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011960241 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.959      |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.92        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0063     |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | -56.6       |
# | time/                   |             |
# |    fps                  | 826         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012765415 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.97        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00852    |
# |    value_loss           | 18.8        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 406      |
# |    ep_rew_mean     | -55.2    |
# | time/              |          |
# |    fps             | 801      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 63488    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 424         |
# |    ep_rew_mean          | -56.5       |
# | time/                   |             |
# |    fps                  | 823         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009102097 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.23        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00829    |
# |    value_loss           | 13.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 447         |
# |    ep_rew_mean          | -52.6       |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008345293 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.405       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.48        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 46.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 463         |
# |    ep_rew_mean          | -46.2       |
# | time/                   |             |
# |    fps                  | 833         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014087158 |
# |    clip_fraction        | 0.0887      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | -0.0493     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | -43.7       |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005932181 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 66.3        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 492      |
# |    ep_rew_mean     | -43      |
# | time/              |          |
# |    fps             | 883      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 73728    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 504         |
# |    ep_rew_mean          | -36.1       |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004879322 |
# |    clip_fraction        | 0.0195      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 77.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 522         |
# |    ep_rew_mean          | -30.5       |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004156597 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.914      |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23          |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 69.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 539         |
# |    ep_rew_mean          | -24.6       |
# | time/                   |             |
# |    fps                  | 890         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.006837695 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.853      |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.3        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 68          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 551          |
# |    ep_rew_mean          | -21.9        |
# | time/                   |              |
# |    fps                  | 938          |
# |    iterations           | 5            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0049567698 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.928       |
# |    explained_variance   | 0.535        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.9         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 75.5         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 570      |
# |    ep_rew_mean     | -16.8    |
# | time/              |          |
# |    fps             | 1272     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 83968    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 582          |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 1181         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0056088506 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.7         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 177          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 598         |
# |    ep_rew_mean          | -7.04       |
# | time/                   |             |
# |    fps                  | 1043        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007062154 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.733      |
# |    explained_variance   | 0.419       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.3        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 129         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 614          |
# |    ep_rew_mean          | -0.737       |
# | time/                   |              |
# |    fps                  | 1003         |
# |    iterations           | 4            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0050856974 |
# |    clip_fraction        | 0.0653       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.2         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00332     |
# |    value_loss           | 75           |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 631        |
# |    ep_rew_mean          | 4.1        |
# | time/                   |            |
# |    fps                  | 954        |
# |    iterations           | 5          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00434823 |
# |    clip_fraction        | 0.0634     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.876     |
# |    explained_variance   | 0.62       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 62.1       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00299   |
# |    value_loss           | 97.4       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 637      |
# |    ep_rew_mean     | 6.44     |
# | time/              |          |
# |    fps             | 1234     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 94208    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 650          |
# |    ep_rew_mean          | 9.66         |
# | time/                   |              |
# |    fps                  | 947          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0073487116 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.932       |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 128          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00498     |
# |    value_loss           | 76.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 661          |
# |    ep_rew_mean          | 11.4         |
# | time/                   |              |
# |    fps                  | 944          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0048413835 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.797       |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 47.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 674         |
# |    ep_rew_mean          | 16.6        |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006752556 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | -0.0866     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61          |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 186         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 680          |
# |    ep_rew_mean          | 17.6         |
# | time/                   |              |
# |    fps                  | 985          |
# |    iterations           | 5            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0048309015 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.473        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 135          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 692      |
# |    ep_rew_mean     | 23.3     |
# | time/              |          |
# |    fps             | 1103     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 104448   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 699          |
# |    ep_rew_mean          | 27.9         |
# | time/                   |              |
# |    fps                  | 1153         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0049531837 |
# |    clip_fraction        | 0.0875       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.902       |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.2         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 116          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 709         |
# |    ep_rew_mean          | 34.2        |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.010178483 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.793      |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51          |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00474    |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 711          |
# |    ep_rew_mean          | 36.1         |
# | time/                   |              |
# |    fps                  | 1165         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0052731633 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | 0.476        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.4         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00346     |
# |    value_loss           | 146          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 718         |
# |    ep_rew_mean          | 40.8        |
# | time/                   |             |
# |    fps                  | 1148        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.011413286 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.5        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00685    |
# |    value_loss           | 133         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 720      |
# |    ep_rew_mean     | 40.8     |
# | time/              |          |
# |    fps             | 1479     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 114688   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 709         |
# |    ep_rew_mean          | 38.6        |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.013804311 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52          |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 148         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 717         |
# |    ep_rew_mean          | 43.3        |
# | time/                   |             |
# |    fps                  | 1086        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.005245856 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.5        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00132    |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 716         |
# |    ep_rew_mean          | 46.5        |
# | time/                   |             |
# |    fps                  | 1035        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.008831322 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.831      |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00259    |
# |    value_loss           | 58.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 708          |
# |    ep_rew_mean          | 50.2         |
# | time/                   |              |
# |    fps                  | 1034         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0043373825 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 78.5         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 91.9         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 697      |
# |    ep_rew_mean     | 57.2     |
# | time/              |          |
# |    fps             | 1360     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 124928   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 686          |
# |    ep_rew_mean          | 59.6         |
# | time/                   |              |
# |    fps                  | 1107         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0036906882 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.778       |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 143          |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00543     |
# |    value_loss           | 96.8         |
# ...
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.739       |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.5         |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 136          |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 518      |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    fps             | 1477     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 268288   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 515         |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 1430        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.004810586 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.679      |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 100         |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 130         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 512         |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.006275817 |
# |    clip_fraction        | 0.0619      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.784      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.43        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 43.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 507          |
# |    ep_rew_mean          | 147          |
# | time/                   |              |
# |    fps                  | 1387         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0049729706 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.904        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11           |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 40.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 504          |
# |    ep_rew_mean          | 149          |
# | time/                   |              |
# |    fps                  | 1399         |
# |    iterations           | 5            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0058045704 |
# |    clip_fraction        | 0.0696       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.654       |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21           |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00281     |
# |    value_loss           | 29.1         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 496      |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    fps             | 2010     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 278528   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | 157         |
# | time/                   |             |
# |    fps                  | 1556        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.005037977 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.3        |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.00453    |
# |    value_loss           | 169         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 484          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 1520         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0024600942 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.703       |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.5         |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 142          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 472         |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 1502        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.005258337 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.9        |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 92.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 471         |
# |    ep_rew_mean          | 162         |
# | time/                   |             |
# |    fps                  | 1489        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.005944167 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.8        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00597    |
# |    value_loss           | 96.5        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 463      |
# |    ep_rew_mean     | 166      |
# | time/              |          |
# |    fps             | 2011     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 288768   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 450         |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 1605        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.003650386 |
# |    clip_fraction        | 0.0194      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.9        |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.00408    |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 454         |
# |    ep_rew_mean          | 172         |
# | time/                   |             |
# |    fps                  | 1496        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.003946194 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.732      |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.4        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 62.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 450          |
# |    ep_rew_mean          | 172          |
# | time/                   |              |
# |    fps                  | 1466         |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0077091325 |
# |    clip_fraction        | 0.0716       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11           |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 55.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 445         |
# |    ep_rew_mean          | 165         |
# | time/                   |             |
# |    fps                  | 1470        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.006727537 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.822       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 125         |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.00271    |
# |    value_loss           | 123         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 441      |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    fps             | 1805     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 299008   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 439          |
# |    ep_rew_mean          | 170          |
# | time/                   |              |
# |    fps                  | 1559         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0059481226 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.744       |
# |    explained_variance   | 0.835        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.3         |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.00399     |
# |    value_loss           | 64.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 441         |
# |    ep_rew_mean          | 169         |
# | time/                   |             |
# |    fps                  | 1462        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 303104      |
# | train/                  |             |
# |    approx_kl            | 0.006156667 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.68        |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | -0.00171    |
# |    value_loss           | 29.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 441         |
# |    ep_rew_mean          | 173         |
# | time/                   |             |
# |    fps                  | 1445        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 305152      |
# | train/                  |             |
# |    approx_kl            | 0.005770136 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.64        |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | -0.000905   |
# |    value_loss           | 18          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 441         |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 1424        |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 307200      |
# | train/                  |             |
# |    approx_kl            | 0.008789499 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.702      |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 110         |
# -----------------------------------------

# %%
for step in range(10):
    obs = env.reset()
    done = False
    while not done:
        env.render()
        observation, reward, terminated, truncated, info = env.step(env.action_space.sample())
        done = terminated or truncated
env.close()
# Out:
# /opt/homebrew/anaconda3/envs/ai_challenge/lib/python3.10/site-packages/gym/envs/box2d/lunar_lander.py:604: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("LunarLander-v2", render_mode="rgb_array")
#   gym.logger.warn(
